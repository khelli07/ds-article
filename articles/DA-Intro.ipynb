# %% [markdown]
# # Pengenalan Data Analysis

# %% [markdown]
# Halo! selamat datang pada laman ini. Perkenalkan, saya Maria Khelli dan saya merupakan mahasiswi ITB Teknik Informatika 2020. Pada artikel ini, selain berkenalan dengan saya, kalian juga akan berkenalan dengan analisis data. Saya akan bawa kalian "jalan-jalan" mulai dari mengapa kita harus belajar data, apa itu analisis data, dan hands-on analisis data dengan Python. Yuk, langsung saja!

# %% [markdown]
# ## **Kenapa, ya, harus belajar data?**

# %% [markdown]
# Perhatikan sekeliling kita. Kita sebetulnya sudah amat dekat dengan data. Apa-apa data, apa-apa data. Ingat laporan praktikum (laprak) kalian? Nah, itu adalah data. Kalau kalian di kamar mandi, pasti kalian pernah iseng membaca komposisi dari shampoo atau sabun kalian bukan? Itu juga adalah data.
#
# Secara definisi, menurut KBBI, data merupakan keterangan atau bahan nyata yang dapat dijadikan dasar analisis atau kesimpulan. Dalam cakupannya di ilmu komputer, data merupakan **informasi** yang dapat diproses oleh komputer. Sejauh ini, **komputer hanya bisa memproses angka**. Jadi, semua informasi yang ingin diproses komputer **harus diubah atau dikonversi ke dalam representasi angka** terlebih dahulu. Meski demikian, hebatnya teknologi sekarang adalah data seperti suara atau gambar yang "tidak ada matematikanya" juga bisa direpresentasikan sebagai angka, lho!
#
# Jadi-jadi, kenapa harus belajar data? Ingat lagi bahwa **data ada di sekeliling kita**. Setiap keputusan yang kita ambil itu juga berdasarkan data yang kita miliki. Nah, data tersebut bentuknya adalah pengalaman. Apabila pengalaman tersebut tidak dimaknai dan dimanfaatkan dengan baik, tidak ada gunanya juga, bukan? Sia-sialah sesuatu yang berharga itu. Sama seperti data, **jika kita tidak bisa memaknai dan memanfaatkannya dengan baik, data tersebut adalah sia-sia.** Padahal, dengan data, kita bisa menjadi lebih peka terhadap keputusan mana yang paling baik. Hal ini mampu memberi kita **peluang untuk menemukan potensi baru.**
#
# Sebenarnya, ada banyak cabang dalam ilmu data, beberapa di antaranya adalah *data science* dan *dan data analytics*. Mereka saling berhubungan satu dan yang lain. *Data analytics* pun juga memiliki beberapa klasifikasi, yaitu sebagai berikut.
# * **Deskriptif**: menjelaskan apa yang terjadi
# * **Diagnostik**: mengapa itu terjadi
# * **Prediktif**: apa yang akan terjadi
# * **Preskriptif**: apa yang harus dilakukan

# %% [markdown]
# <img src="../assets/principa-4-types-of-da.png"></img>
# <br> Sumber: [KD Nuggets](https://www.kdnuggets.com/2017/07/4-types-data-analytics.html)

# %% [markdown]
# Dalam artikel ini, kita hanya akan membahas analisis data, khususnya analisis deskriptif. Kenapa? Karena ilmu ini merupakan ilmu paling dasar dan ilmu paling umum. Jadi, prinsip-prinsip analisis data yang kalian pelajari di sini dapat kalian terapkan dalam bidang ilmu yang kalian tekuni sekarang. *Anyway, meskipun ada dari kalian yang tidak menjurus ke informatika, belajar data secara mendalam nggak ada salahnya, kok!*

# %% [markdown]
# ## **Lalu, apa itu analisis data?**

# %% [markdown]
# Menurut Wikipedia, analisis data adalah proses mengkaji (menginspeksi), mentransformasikan, dan memodelkan data **dengan tujuan untuk menemukan informasi yang berguna, menarik kesimpulan, dan mendukung pengambilan keputusan.** Sementara itu, Milton berpendapat bahwa analisis data adalah cara untuk **memecah masalah yang kompleks menjadi beberapa bagian** sehingga dapat **mengetahui akar masalahnya.**
#
# Dalam analisis data, tentu ada tahap-tahap yang harus dilakukan. Tahap tahap tersebut diilustrasikan pada gambar di bawah ini.

# %% [markdown]
# <img src="../assets/da-workflow.png"></img>
# <br> Sumber: Milton, Michael. 2009. *Head First Data Analysis*. USA: O'Reilly

# %% [markdown]
# Agar memudahkan, mari simak contoh sederhana berikut. Misalkan kamu adalah seorang pelajar perantau yang sedang kebingungan ingin makan apa pada sore hari. Uangmu untuk jatah hari ini hanya sisa Rp50.000, tentu artinya kamu tidak boleh belanja lebih dari ini. Kamu bisa memilih untuk berjalan kaki dan membeli makan sendiri jika warung makannya dekat dengan tempat tinggalmu atau menggunakan layanan ojek *online* (ojol) untuk mengantarkan makanannya. Kamu sedang ada tugas sehingga tidak punya banyak waktu untuk memasak.
#
# **1. Define**: apa yang menjadi masalahmu? <br>
#
# Sebaiknya definisi masalah berbentuk pertanyaan (ingat rumusan masalah dalam karya ilmiah). Dalam hal ini, contoh permasalahannya adalah "Bagaimana memilih makanan yang tepat untuk dibeli pada sore hari ini?"
#
# **2. Disassemble**: uraikan permasalahan menjadi masalah yang lebih kecil. <br>
#
# Terkadang, rumusan masalah terlalu luas sehingga pertanyaannya tidak dapat dijawab secara langsung. Maka, untuk masalah-masalah yang belum jelas coba didiskusikan terlebih dahulu dengan orang yang terlibat, misalnya jika kamu memiliki *client*. Untuk hal ini, karena ini masalahmu sendiri, kamu bisa mempertimbangkan beberapa hal. Contohnya sebagai berikut.
#     * "Apa yang sedang ingin kamu makan? Apakah sesuatu yang asin atau manis?"
#     * "Apakah budget kamu cukup? Lebih hemat jalan kaki atau ojol? "
#     * "Seberapa banyak kamu ingin makan? Apakah lebih banyak lebih baik?"
#     * "Apakah makanan yang ingin dibeli higienis?"
#     * "Adakah warung makan lain yang menjual makanan yang sejenis tetapi lebih murah dan tetap higienis?"
#     * dan lain-lain.
# Jumlah pertanyaannya bebas. Tidak harus banyak dan tidak harus sedikit. Selama pertanyaan-pertanyaan tersebut cukup untuk membantumu menyelesaikan masalahmu, maka pertanyaan tersebut sudah tepat jumlahnya.
#
# **3. Evaluate**: amati permasalahanmu sebelumnya, kemudian bandingkan dengan data <br>
#
# Pada contoh ini, data-data yang kamu miliki bisa berasal dari internet (ulasan orang lain, rating, dan sejenisnya), pengalaman kamu, maupun cerita dari temanmu. **INGAT !!** Kamu tidak boleh memasukkan pengalamanmu sebagai data jika masalahnya merupakan masalah perusahaan. **Input data harus sesuai dengan permasalahanmu**. Pada permasalahan yang nyata, misalnya omset penjualan baju, data yang dimiliki biasanya berbentuk tabular... atau kamu bisa ingat laporan praktikummu lagi! Di sana, kamu tidak dapat memasukkan pengalamanmu sebagai input data, bukan? <br>
# Baik, mari kembali pada mengamati permasalahan dan data. Contohnya adalah sebagai berikut.
#
# **Observasi terhadap permasalahan** <br>
# * Kamu sedang ingin makan makanan yang asin.
# * Budget yang dimiliki sebesar Rp50.000.
# * Sore ini kamu lapar, jadi harus makan banyak.
#
# **Observasi terhadap data** <br>
# * Di dekat rumah ada warung makan mi ayam. Di sisi lain, warung makanan yang tersedia pada layanan ojol juga banyak yang masih belum tutup.
# * Warung makan dekat rumah memang murah dan hemat ongkos kirim, tetapi ternyata layanan ojol menyediakan diskon sehingga harga layanan ojol lebih murah.
# * Pilihan makanan di layanan ojol lebih banyak, tidak hanya mi ayam. Kamu bisa memilih makanan lain dengan volume yang banyak, tetapi tetap mendapat harga yang murah.
#
# **4. Decide**: berisi kesimpulan dan saran dari analisis yang kamu lakukan. <br>
#
# Pada bagian ini, kamu bisa memasukkan pengalaman kamu sebagai opini. Kesimpulan dan saran pada contoh ini misalnya, makanan yang paling baik dibeli sore hari ini adalah makanan Padang. Harganya sekitar setengah dari budget karena ada promosi dari layanan ojol. Menurutmu, ini pilihan yang baik karena waktu itu pernah membeli dan rasanya enak (pengalaman).

# %% [markdown]
# ## **Tunggu, tunggu, tunggu, masih ada yang lupa! Ternyata dalam analisis deskriptif, kita harus mengetahui tipe data yang kita miliki**

# %% [markdown]
# Pada contoh sebelumnya, kamu telah membaca *workflow* analisis data secara umum. Kenyataannya, permasalahan bisa lebih kompleks daripada itu. Maka dari itu, kita harus mengetahui tipe-tipe data yang ada. Tipe data yang berbeda memiliki cara penanganan yang berbeda. Yuk, kita simak sebelum **hands-on**!!

# %% [markdown]
# ## Data Kuantitatif dan Kualitatif
# Sebagian dari kalian mungkin sudah mengetahui perbedaan kedua tipe data tersebut.
# * Data **kuantitatif** merujuk pada data numerik. Misalnya, kecepatan, percepatan, atau jumlah buku.
#
# * Data **kualitatif** merujuk pada informasi tentang kualitas (tentunya), yaitu informasi yang tidak dapat dihitung. Misalnya, warna mata seseorang atau program studi seseorang.
#
# ### **Data Kuantitatif**
# Data kuantitatif dapat dibagi menjadi dua: diskrit dan kontinu. Perbedaannya apa?
# * **Diskrit** merupakan data yang berbentuk bilangan bulat. Misalnya, jumlah anjing peliharaan dalam rumah. Kamu tidak bisa memiliki satu-setengah anjing. Contoh lain adalah jumlah halaman pada sebuah buku.
#
# * **Kontinu** merupakan data yang bisa dinyatakan dalam bentuk bilangan pecahan atau desimal. Biasanya, data ini berbentuk rasional. Jika tidak rasional, akan dilakukan pembulatan sehingga menjadi rasional. Contoh data kontinu adalah harga sebuah buku, durasi waktu, dan tinggi badan.
#
# ### **Data Kualitatif**
# Meski data kualitatif menunjukkan kualitas yang tidak dapat dihitung, ingat bahwa komputer hanya dapat memproses angka. Maka dari itu, jika ingin diproses, harus diubah ke dalam representasi angka terlebih dahulu. Data kualitatif dibagi menjadi tiga:
# * **Nominal**: Data yang digunakan sebagai variabel untuk merepresentasikan, misalnya warna rambut. Contohnya adalah 1: hijau, 2: merah, 3: kuning, 4: biru. Urutannya bebas, asal konsisten. Angka 1 dan 4 di sini tidak dapat dibandingkan dalam artian 1 tidak lebih kecil dari 4 karena hijau dan biru tidak ada relasi besar-kecil.
#
# * **Ordinal**: Pada tipe ini, data memiliki relasi besar-kecil. Namun, definisi besar-kecilnya didefinisikan pada yang membuat data. Contohnya adalah skala kepuasan (rating) terhadap makanan. Data ini memiliki keterurutan. Dalam skala 1-100, angka 100 "lebih baik" daripada angka 99 (bergantung definisi skalanya, bisa terbalik). Skala juga bisa didefinisikan 1-5 atau 1-10 saja. Ordinal bisa diperlakukan sebagai diskrit atau kontinu.
# <br> Lalu, mengapa ini tak masuk dalam kategori kuantitatif? Dalam kuantitatif, misal jumlah halaman buku adalah 231 halaman. Namun, apakah buku dengan 231 halaman pasti "lebih baik" daripada buku dengan 230 halaman? Tentu tidak.
#
# * **Binary**: Seperti namanya, data ini hanya memiliki nilai biner "0" atau "1" seperti "false" atau "true" saja. Contohnya adalah absensi mahasiswa. Seorang mahasiswa dapat dikategorikan sebagai hadir (1) atau tidak hadir (0). Sebenarnya, representasi 0/1 bisa bebas, tetapi disarankan nilai "0" hanya untuk yang tidak memenuhi kondisi saja, dan *vice versa*.

# %% [markdown]
# <img src="../assets/scales-table.png"></img>
# <br> Sumber: Moreira et al. 2019. *A General Introduction to Data Analytics*. USA: John Wiley & Sons, Inc

# %% [markdown]
# ## Skala Perhitungan
# Skala perhitungan merupakan cara sebuah variabel didefinisikan. Dengan kata lain, kita menginterpretasikan maksud dari data melalui kategorinya dalam skala perhitungan. Beberapa klasifikasinya adalah sebagai berikut.
#
# * **Nominal**: merupakan angka yang merepresentasikan variabel sehingga tidak ada keterurutan.
# * **Ordinal**: mendeskripsikan data menurut keterurutan tertentu. Keterurutan tersebut didefinisikan oleh pembuat data.
# * **Interval**: skala ini memiliki kekhususan yaitu bahwa nilai nol "0" merupakan nilai yang benar-benar ada dan memiliki arti, misalnya temperatur nol derajat Celcius (*NO TRUE ZERO*). Selain itu, data dengan tipe ini memiliki selisih yang sama di antara mereka(*equally spaced*). Misalnya selisih antara 10 dan 20 derajat dengan 20 dan 30 derajat adalah sama.
# * **Ratio**: perbedaan paling mencolok adalah dengan interval. Tipe skala rasio memiliki nilai absolut nol. Misalnya, jika berat badanmu 0kg, artinya kamu tidak ada.

# %% [markdown]
# References:
# 1. Milton, Michael. 2009. *Head First Data Analysis*. USA: O'Reilly
# 1. Moreira et al. 2019. *A General Introduction to Data Analytics*. USA: John Wiley & Sons, Inc
# 1. https://studyonline.unsw.edu.au/blog/types-of-data
# 1. https://www.kdnuggets.com/2017/07/4-types-data-analytics.html

# %% [markdown]
# # Hands-On Data Analysis with Python

# %% [markdown]
# Prerequisite:
# * Kamu sudah baca pengantar analisis data.
# * Kamu harus sudah familiar dengan Python, mengerti dasar-dasar Python seperti tipe data, variabel, struktur data sederhana seperti array dan matriks, control flow (if-else, loops), dan mengetahui cara kerja library dalam Python.

# %% [markdown]
# Sebelum mulai, silakan unduh dataset dari [Kaggle](https://www.kaggle.com/komalkhetlani/nutritional-content-of-cereals).

# %% [markdown]
# ## Making Data Frame (anggap saja tabel)

# %%
#Tentunya harus import library Pandas terlebih dahulu
import pandas as pd 

# Membuat dataset - Cara 1
tabel = {"Kolom_00": ["Baris_00", "Baris_00", "Baris_00"],
            "Kolom_01": ["Baris_01", "Baris_01", "Baris_01"],
            "Kolom_02": ["Baris_02", "Baris_02", "Baris_02"]}

dataFrame1 = pd.DataFrame(data=tabel) #perhatikan huruf besar-kecil!!
print(dataFrame1)
# Out:
#    Kolom_00  Kolom_01  Kolom_02
# 0  Baris_00  Baris_01  Baris_02
# 1  Baris_00  Baris_01  Baris_02
# 2  Baris_00  Baris_01  Baris_02

# %%
# Membuat dataset - Cara 2
tabel2 = {"JENIS_BARANG" : pd.Series(['Susu', 'Telur', 'Gula'], index=['u', 'v', 'w']),
        "KUANTITAS": pd.Series(['10', '3', '9'], index=['u','v','w'])}
        
dataFrame2 = pd.DataFrame(tabel2)
print(dataFrame2)
# Out:
#   JENIS_BARANG KUANTITAS
# u         Susu        10
# v        Telur         3
# w         Gula         9

# %% [markdown]
# ## Load dan Output Data Frame

# %%
'''
Sudah download dataset dari link Kaggle di atas? Unzip, lalu letakkan pada sebuah folder bernama "datasets". Jadi struktur foldernya adalah:
- namafilekamu.ipynb
- datasets
    - cereal.csv
'''

# Load dataset
df = pd.read_csv("datasets/cereal.csv")

# Menampilkan datasetnya tidak harus menggunakan print
df.head()
# Out:
#                         name          mfr         type calories protein  fat  \
# 0                     String  Categorical  Categorical      Int     Int  Int
# 1                  100% Bran            N            C       70       4    1
# 2          100% Natural Bran            Q            C      120       3    5
# 3                   All-Bran            K            C       70       4    1
# 4  All-Bran with Extra Fiber            K            C       50       4    0
#
#   sodium  fiber  carbo sugars potass vitamins shelf weight   cups     rating
# 0    Int  Float  Float    Int    Int      Int   Int  Float  Float      Float
# 1    130     10      5      6    280       25     3      1   0.33  68.402973
# 2     15      2      8      8    135        0     3      1      1  33.983679
# 3    260      9      7      5    320       25     3      1   0.33  59.425505
# 4    140     14      8      0    330       25     3      1    0.5  93.704912

# %%
# Head: menampilkan 5 data teratas
# Tail: menampilkan 5 data terakhir
df.tail()
# Out:
#                    name mfr type calories protein fat sodium fiber carbo  \
# 73              Triples   G    C      110       2   1    250     0    21
# 74                 Trix   G    C      110       1   1    140     0    13
# 75           Wheat Chex   R    C      100       3   1    230     3    17
# 76             Wheaties   G    C      100       3   1    200     3    17
# 77  Wheaties Honey Gold   G    C      110       2   1    200     1    16
#
#    sugars potass vitamins shelf weight  cups     rating
# 73      3     60       25     3      1  0.75  39.106174
# 74     12     25       25     2      1     1  27.753301
# 75      3    115       25     1      1  0.67  49.787445
# 76      3    110       25     1      1     1  51.592193
# 77      8     60       25     1      1  0.75  36.187559

# %%
#Bisa dimasukkan argumen, misal 10 data teratas, berarti
df.head(10)
# Out:
#                         name          mfr         type calories protein  fat  \
# 0                     String  Categorical  Categorical      Int     Int  Int
# 1                  100% Bran            N            C       70       4    1
# 2          100% Natural Bran            Q            C      120       3    5
# 3                   All-Bran            K            C       70       4    1
# 4  All-Bran with Extra Fiber            K            C       50       4    0
# 5             Almond Delight            R            C      110       2    2
# 6    Apple Cinnamon Cheerios            G            C      110       2    2
# 7                Apple Jacks            K            C      110       2    0
# 8                    Basic 4            G            C      130       3    2
# 9                  Bran Chex            R            C       90       2    1
#
#   sodium  fiber  carbo sugars potass vitamins shelf weight   cups     rating
# 0    Int  Float  Float    Int    Int      Int   Int  Float  Float      Float
# 1    130     10      5      6    280       25     3      1   0.33  68.402973
# 2     15      2      8      8    135        0     3      1      1  33.983679
# 3    260      9      7      5    320       25     3      1   0.33  59.425505
# 4    140     14      8      0    330       25     3      1    0.5  93.704912
# 5    200      1     14      8     -1       25     3      1   0.75  34.384843
# 6    180    1.5   10.5     10     70       25     1      1   0.75  29.509541
# 7    125      1     11     14     30       25     2      1      1  33.174094
# 8    210      2     18      8    100       25     3   1.33   0.75  37.038562
# 9    200      4     15      6    125       25     1      1   0.67  49.120253

# %% [markdown]
# Data di atas menggunakan CSV (Comma Separated Values). <br>
# Untuk CSV yang menggunakan delimiter selain koma, kamu bisa gunakan <br>
# df = pd.read_csv("path/namafile.csv", delimiter=";") <br>
# atau <br>
# df = pd.read_csv("path/namafile.csv", sep=";") <br>
#
# Untuk membaca data excel berekstensi .xlsx, kamu bisa gunakan <br>
# df = pd.read_excel("path/namafile.xlsx")

# %%
# Kita bisa melihat dimensi dataset dengan command berikut
df.shape
# Out:
# (78, 16)

# %%
'''Artinya, dataset kita memiliki 78 baris dan 16 kolom. Kita bisa cek dengan teknkik yang sudah kita gunakan tadi
Terlihat bahwa index terakhir adalah 77, ingat bahwa kita mulai dari 0, jadi benar bahwa ada 78 baris.
'''
df.tail(3)
# Out:
#                    name mfr type calories protein fat sodium fiber carbo  \
# 75           Wheat Chex   R    C      100       3   1    230     3    17
# 76             Wheaties   G    C      100       3   1    200     3    17
# 77  Wheaties Honey Gold   G    C      110       2   1    200     1    16
#
#    sugars potass vitamins shelf weight  cups     rating
# 75      3    115       25     1      1  0.67  49.787445
# 76      3    110       25     1      1     1  51.592193
# 77      8     60       25     1      1  0.75  36.187559

# %% [markdown]
# ## Dumping NaN Values

# %%
'''Untuk memperlancar analisis, biasanya orang akan membuang data NaN (not a number). 
Kalau di matematika, nilainya seperti sqrt(-1) alias imajiner.
Data akan dibuang jika memang jumlahnya tidak banyak. 
Jika jumlahnya banyak, ada cara lain untuk menanganinya. Untuk sekarang, kita belum sampai sana.
'''

df.dropna(inplace=True)

# %% [markdown]
# ## Selecting Data

# %%
# Untuk memilih data, kita bisa menggunakan .loc dan .iloc, bedanya apa?

df.iloc[:4] #lihat indeks hanya dari nol sampai 3 (seperti slicing list)
# Out:
#                 name          mfr         type calories protein  fat sodium  \
# 0             String  Categorical  Categorical      Int     Int  Int    Int
# 1          100% Bran            N            C       70       4    1    130
# 2  100% Natural Bran            Q            C      120       3    5     15
# 3           All-Bran            K            C       70       4    1    260
#
#    fiber  carbo sugars potass vitamins shelf weight   cups     rating
# 0  Float  Float    Int    Int      Int   Int  Float  Float      Float
# 1     10      5      6    280       25     3      1   0.33  68.402973
# 2      2      8      8    135        0     3      1      1  33.983679
# 3      9      7      5    320       25     3      1   0.33  59.425505

# %%
# Bedakan dengan .loc
df.loc[:4] #lihat, indeks dari nol sampai 4
# Out:
#                         name          mfr         type calories protein  fat  \
# 0                     String  Categorical  Categorical      Int     Int  Int
# 1                  100% Bran            N            C       70       4    1
# 2          100% Natural Bran            Q            C      120       3    5
# 3                   All-Bran            K            C       70       4    1
# 4  All-Bran with Extra Fiber            K            C       50       4    0
#
#   sodium  fiber  carbo sugars potass vitamins shelf weight   cups     rating
# 0    Int  Float  Float    Int    Int      Int   Int  Float  Float      Float
# 1    130     10      5      6    280       25     3      1   0.33  68.402973
# 2     15      2      8      8    135        0     3      1      1  33.983679
# 3    260      9      7      5    320       25     3      1   0.33  59.425505
# 4    140     14      8      0    330       25     3      1    0.5  93.704912

# %%
# Agar lebih paham, coba simak dataframe susu-telur-gula yang sudah kita buat tadi
dataFrame2.iloc[:2]
# Out:
#   JENIS_BARANG KUANTITAS
# u         Susu        10
# v        Telur         3

# %%
# Perhatikan! Indeks dari dataFrame2 adalah u, v, dan w. Kita coba menggunakan loc
dataFrame2.loc[:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16416/2640648799.py in <module>
#       1 # Perhatikan! Indeks dari dataFrame2 adalah u, v, dan w. Kita coba menggunakan loc
# ----> 2 dataFrame2.loc[:2]
#
# C:\Python39\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# C:\Python39\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1140         if isinstance(key, slice):
#    1141             self._validate_key(key, axis)
# -> 1142             return self._get_slice_axis(key, axis=axis)
#    1143         elif com.is_bool_indexer(key):
#    1144             return self._getbool_axis(key, axis=axis)
#
# C:\Python39\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1174
#    1175         labels = obj._get_axis(axis)
# -> 1176         indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1177
#    1178         if isinstance(indexer, slice):
#
# C:\Python39\lib\site-packages\pandas\core\indexes\base.py in slice_indexer(self, start, end, step, kind)
#    5684         slice(1, 3, None)
#    5685         """
# -> 5686         start_slice, end_slice = self.slice_locs(start, end, step=step)
#    5687
#    5688         # return a slice
#
# C:\Python39\lib\site-packages\pandas\core\indexes\base.py in slice_locs(self, start, end, step, kind)
#    5892         end_slice = None
#    5893         if end is not None:
# -> 5894             end_slice = self.get_slice_bound(end, "right")
#    5895         if end_slice is None:
#    5896             end_slice = len(self)
#
# C:\Python39\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    5796         # For datetime indices label may be a string that has to be converted
#    5797         # to datetime boundary according to its resolution.
# -> 5798         label = self._maybe_cast_slice_bound(label, side)
#    5799
#    5800         # we need to look up the label
#
# C:\Python39\lib\site-packages\pandas\core\indexes\base.py in _maybe_cast_slice_bound(self, label, side, kind)
#    5748         # reject them, if index does not contain label
#    5749         if (is_float(label) or is_integer(label)) and label not in self._values:
# -> 5750             raise self._invalid_indexer("slice", label)
#    5751
#    5752         return label
#
# TypeError: cannot do slice indexing on Index with these indexers [2] of type int

# %% [markdown]
# Terjadi error! Mengapa? karena .loc mengakses lewat "indeks" sesuai dataframe kita, sedangkan .iloc mengakses lewat urutan "baris" (tidak peduli indeksnya apa pun). <br>
# Mari kita coba lagi.

# %%
dataFrame2.loc[:'v'] # Perhatikan, harus berupa karakter! (menggunakan tanda petik)
# Out:
#   JENIS_BARANG KUANTITAS
# u         Susu        10
# v        Telur         3

# %% [markdown]
# Sebenarnya, bisa saja tanpa menggunakan .loc atau .iloc, tetapi tidak disarankan. Jika indeks tidak berupa angka, akan terjadi error seperti tadi.

# %%
# Kembali ke dataset sereal
df.head()
# Out:
#                         name          mfr         type calories protein  fat  \
# 0                     String  Categorical  Categorical      Int     Int  Int
# 1                  100% Bran            N            C       70       4    1
# 2          100% Natural Bran            Q            C      120       3    5
# 3                   All-Bran            K            C       70       4    1
# 4  All-Bran with Extra Fiber            K            C       50       4    0
#
#   sodium  fiber  carbo sugars potass vitamins shelf weight   cups     rating
# 0    Int  Float  Float    Int    Int      Int   Int  Float  Float      Float
# 1    130     10      5      6    280       25     3      1   0.33  68.402973
# 2     15      2      8      8    135        0     3      1      1  33.983679
# 3    260      9      7      5    320       25     3      1   0.33  59.425505
# 4    140     14      8      0    330       25     3      1    0.5  93.704912

# %%
# Misal kita ingin melakukan seleksi dari baris ke-55 sampai baris ke-60 kolom kalori, protein, sampai dengan vitamin.
# Kita dapat melakukannya dengan
df.loc[55:60, "calories": "vitamins"]
# Out:
#    calories protein fat sodium fiber carbo sugars potass vitamins
# 55       50       1   0      0     0    13      0     15        0
# 56       50       2   0      0     1    10      0     50        0
# 57      100       4   1    135     2    14      6    110       25
# 58      100       5   2      0   2.7    -1     -1    110        0
# 59      120       3   1    210     5    14     12    240       25
# 60      100       3   2    140   2.5  10.5      8    140       25

# %%
# Untuk memilih kolom tertentu, kita bisa menggunakan
df['name'].head()
# Out:
# 0                       String
# 1                    100% Bran
# 2            100% Natural Bran
# 3                     All-Bran
# 4    All-Bran with Extra Fiber
# Name: name, dtype: object

# %%
# atau
df.name.head() #syntax kedua dipakai jika nama kolom tidak punya spasi
# Out:
# 0                       String
# 1                    100% Bran
# 2            100% Natural Bran
# 3                     All-Bran
# 4    All-Bran with Extra Fiber
# Name: name, dtype: object

# %%
# Kita juga bisa memberikan kondisional pada dataset, misalnya
df[df.rating >= 60]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16416/3754710783.py in <module>
#       1 # Kita juga bisa memberikan kondisional pada dataset, misalnya
# ----> 2 df[df.rating >= 60]
#
# C:\Python39\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# C:\Python39\lib\site-packages\pandas\core\arraylike.py in __ge__(self, other)
#      50     @unpack_zerodim_and_defer("__ge__")
#      51     def __ge__(self, other):
# ---> 52         return self._cmp_method(other, operator.ge)
#      53
#      54     # -------------------------------------------------------------
#
# C:\Python39\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5499
#    5500         with np.errstate(all="ignore"):
# -> 5501             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5502
#    5503         return self._construct_result(res_values, name=res_name)
#
# C:\Python39\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     282
#     283     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 284         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285
#     286     else:
#
# C:\Python39\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      71         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72     else:
# ---> 73         result = libops.scalar_compare(x.ravel(), y, op)
#      74     return result.reshape(x.shape)
#      75
#
# C:\Python39\lib\site-packages\pandas\_libs\ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %% [markdown]
# Oops, sepertinya kita perlu melakukan manipulasi terlebih dahulu.

# %% [markdown]
# ## Manipulating Data Frame

# %%
# Untuk mengecek tipe data, kita bisa menggunakan command
df.dtypes
# Out:
# name        object
# mfr         object
# type        object
# calories    object
# protein     object
# fat         object
# sodium      object
# fiber       object
# carbo       object
# sugars      object
# potass      object
# vitamins    object
# shelf       object
# weight      object
# cups        object
# rating      object
# dtype: object

# %% [markdown]
# Terlihat bahwa semua kolom kita merupakan tipe objek. Sebenarnya, pada baris indeks nol, diberitahukan jenis datanya. Kita bisa mengikuti itu (kalau tidak juga tidak apa-apa, tetapi mari ikuti saja). Oh iya, apa itu objek dalam Pandas? Untuk sekarang, sebenarnya tidak masalah jika kalian ingin menganggap objek tersebut sebagai string saja. Jika ingin penjelasan lebih lanjut, kalian bisa kunjungi laman [berikut](https://stackoverflow.com/questions/34881079/pandas-distinction-between-str-and-object-types).

# %%
# Mari lihat tipe data awalnya
df.iloc[:2]
# Out:
#         name          mfr         type calories protein  fat sodium  fiber  \
# 0     String  Categorical  Categorical      Int     Int  Int    Int  Float
# 1  100% Bran            N            C       70       4    1    130     10
#
#    carbo sugars potass vitamins shelf weight   cups     rating
# 0  Float    Int    Int      Int   Int  Float  Float      Float
# 1      5      6    280       25     3      1   0.33  68.402973

# %%
# Untuk melakukan casting (perubahan tipe data) dari objek ke, misalnya, string, integer, atau float, 
# kita harus ubah dataset utama kita terlebih dahulu
df = df.iloc[1:]
df.head()
# Out:
#                         name mfr type calories protein fat sodium fiber carbo  \
# 1                  100% Bran   N    C       70       4   1    130    10     5
# 2          100% Natural Bran   Q    C      120       3   5     15     2     8
# 3                   All-Bran   K    C       70       4   1    260     9     7
# 4  All-Bran with Extra Fiber   K    C       50       4   0    140    14     8
# 5             Almond Delight   R    C      110       2   2    200     1    14
#
#   sugars potass vitamins shelf weight  cups     rating
# 1      6    280       25     3      1  0.33  68.402973
# 2      8    135        0     3      1     1  33.983679
# 3      5    320       25     3      1  0.33  59.425505
# 4      0    330       25     3      1   0.5  93.704912
# 5      8     -1       25     3      1  0.75  34.384843

# %%
# Baris pertama telah hilang, maka kita bisa lakukan casting (lakukan ini per kolom karena beda kolom beda tipe data).
# Kita coba casting kolom terakhir
df.rating = df.rating.astype(float)
df.calories = df.calories.astype(int)
df.protein = df.protein.astype(int)
df.fat = df.fat.astype(int)
df.sodium = df.sodium.astype(int)
df.fiber = df.fiber.astype(float)
df.carbo = df.carbo.astype(float)
df.sugars = df.sugars.astype(float)
df.potass = df.potass.astype(float)
df.vitamins = df.vitamins.astype(float)
df.shelf = df.shelf.astype(float)
df.weight = df.weight.astype(float)
df.cups = df.cups.astype(float)

df.rating.dtype
# Out:
# dtype('float64')

# %%
# Lihat tipe datanya berubah dari objek ke float64. Sekarang, kita bisa lakukan seleksi kondisional pada kolom rating
df[df.rating >= 60] # Terlihat bahwa yang muncul hanya ketika rating lebih dari 60
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 1                   100% Bran   N    C        70        4    1     130   10.0
# 4   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 21     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 55                Puffed Rice   Q    C        50        1    0       0    0.0
# 56               Puffed Wheat   Q    C        50        2    0       0    1.0
# 64             Shredded Wheat   N    C        80        2    0       0    3.0
# 65     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 66  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 1     5.0     6.0   280.0      25.0    3.0    1.00  0.33  68.402973
# 4     8.0     0.0   330.0      25.0    3.0    1.00  0.50  93.704912
# 21   21.0     0.0    -1.0       0.0    2.0    1.00  1.00  64.533816
# 55   13.0     0.0    15.0       0.0    3.0    0.50  1.00  60.756112
# 56   10.0     0.0    50.0       0.0    3.0    0.50  1.00  63.005645
# 64   16.0     0.0    95.0       0.0    1.0    0.83  1.00  68.235885
# 65   19.0     0.0   140.0       0.0    1.0    1.00  0.67  74.472949
# 66   20.0     0.0   120.0       0.0    1.0    1.00  0.67  72.801787

# %%
# Kita juga bisa menyeleksi dengan 2 kondisi
df[(df.rating >= 60) & (df.type == 'C')] # Gunakan tanda kurung untuk meminimalisasi error
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 1                   100% Bran   N    C        70        4    1     130   10.0
# 4   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 55                Puffed Rice   Q    C        50        1    0       0    0.0
# 56               Puffed Wheat   Q    C        50        2    0       0    1.0
# 64             Shredded Wheat   N    C        80        2    0       0    3.0
# 65     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 66  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 1     5.0     6.0   280.0      25.0    3.0    1.00  0.33  68.402973
# 4     8.0     0.0   330.0      25.0    3.0    1.00  0.50  93.704912
# 55   13.0     0.0    15.0       0.0    3.0    0.50  1.00  60.756112
# 56   10.0     0.0    50.0       0.0    3.0    0.50  1.00  63.005645
# 64   16.0     0.0    95.0       0.0    1.0    0.83  1.00  68.235885
# 65   19.0     0.0   140.0       0.0    1.0    1.00  0.67  74.472949
# 66   20.0     0.0   120.0       0.0    1.0    1.00  0.67  72.801787

# %% [markdown]
# ## Sorting

# %%
'''
Kita bisa melakukan pengurutan dengan dataset menggunakan command df.sort_values. Argumen by merupakan kolom yang ingin menjadi acuan saat sorting, kemudian argumen ascending merupakan 'mode' pengurutan, apakah besar -> kecil (ascending=False) atau kecil -> besar (ascending=True). Bisa kalian substitusi True dengan [1] dan False dengan [0].
'''

df.sort_values(by='calories', ascending=True)
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 4   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 55                Puffed Rice   Q    C        50        1    0       0    0.0
# 56               Puffed Wheat   Q    C        50        2    0       0    1.0
# 1                   100% Bran   N    C        70        4    1     130   10.0
# 3                    All-Bran   K    C        70        4    1     260    9.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 8                     Basic 4   G    C       130        3    2     210    2.0
# 40     Just Right Fruit & Nut   K    C       140        3    1     170    2.0
# 50  Nutri-Grain Almond-Raisin   K    C       140        3    2     220    3.0
# 71          Total Raisin Bran   G    C       140        3    1     190    4.0
# 47       Mueslix Crispy Blend   K    C       160        3    2     150    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 4     8.0     0.0   330.0      25.0    3.0    1.00  0.50  93.704912
# 55   13.0     0.0    15.0       0.0    3.0    0.50  1.00  60.756112
# 56   10.0     0.0    50.0       0.0    3.0    0.50  1.00  63.005645
# 1     5.0     6.0   280.0      25.0    3.0    1.00  0.33  68.402973
# 3     7.0     5.0   320.0      25.0    3.0    1.00  0.33  59.425505
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 8    18.0     8.0   100.0      25.0    3.0    1.33  0.75  37.038562
# 40   20.0     9.0    95.0     100.0    3.0    1.30  0.75  36.471512
# 50   21.0     7.0   130.0      25.0    3.0    1.33  0.67  40.692320
# 71   15.0    14.0   230.0     100.0    3.0    1.50  1.00  28.592785
# 47   17.0    13.0   160.0      25.0    3.0    1.50  0.67  30.313351
#
# [74 rows x 16 columns]

# %%
# Kita juga bisa melakukan dua sort sekaligus
'''
Cara kerja kodenya: sorting berdasarkan calories terlebih dahulu. Jika sama, lalu sorting untuk rating.
Jika terbalik, hasil keluaran akan berbeda.
'''
df.sort_values(by=['calories', 'rating'], ascending=[1, 1])
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 55                Puffed Rice   Q    C        50        1    0       0    0.0
# 56               Puffed Wheat   Q    C        50        2    0       0    1.0
# 4   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 3                    All-Bran   K    C        70        4    1     260    9.0
# 1                   100% Bran   N    C        70        4    1     130   10.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 8                     Basic 4   G    C       130        3    2     210    2.0
# 71          Total Raisin Bran   G    C       140        3    1     190    4.0
# 40     Just Right Fruit & Nut   K    C       140        3    1     170    2.0
# 50  Nutri-Grain Almond-Raisin   K    C       140        3    2     220    3.0
# 47       Mueslix Crispy Blend   K    C       160        3    2     150    3.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 55   13.0     0.0    15.0       0.0    3.0    0.50  1.00  60.756112
# 56   10.0     0.0    50.0       0.0    3.0    0.50  1.00  63.005645
# 4     8.0     0.0   330.0      25.0    3.0    1.00  0.50  93.704912
# 3     7.0     5.0   320.0      25.0    3.0    1.00  0.33  59.425505
# 1     5.0     6.0   280.0      25.0    3.0    1.00  0.33  68.402973
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 8    18.0     8.0   100.0      25.0    3.0    1.33  0.75  37.038562
# 71   15.0    14.0   230.0     100.0    3.0    1.50  1.00  28.592785
# 40   20.0     9.0    95.0     100.0    3.0    1.30  0.75  36.471512
# 50   21.0     7.0   130.0      25.0    3.0    1.33  0.67  40.692320
# 47   17.0    13.0   160.0      25.0    3.0    1.50  0.67  30.313351
#
# [74 rows x 16 columns]

# %%
df.sort_values(by=['rating', 'calories'], ascending=[1, 1]) #Berbeda kan?
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 11               Cap'n'Crunch   Q    C       120        1    2     220    0.0
# 13      Cinnamon Toast Crunch   G    C       120        1    3     210    0.0
# 36           Honey Graham Ohs   Q    C       120        1    2     220    1.0
# 19              Count Chocula   G    C       110        1    1     180    0.0
# 15                Cocoa Puffs   G    C       110        1    1     180    0.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 64             Shredded Wheat   N    C        80        2    0       0    3.0
# 1                   100% Bran   N    C        70        4    1     130   10.0
# 66  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 65     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 4   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 11   12.0    12.0    35.0      25.0    2.0    1.00  0.75  18.042851
# 13   13.0     9.0    45.0      25.0    2.0    1.00  0.75  19.823573
# 36   12.0    11.0    45.0      25.0    2.0    1.00  1.00  21.871292
# 19   12.0    13.0    65.0      25.0    2.0    1.00  1.00  22.396513
# 15   12.0    13.0    55.0      25.0    2.0    1.00  1.00  22.736446
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 64   16.0     0.0    95.0       0.0    1.0    0.83  1.00  68.235885
# 1     5.0     6.0   280.0      25.0    3.0    1.00  0.33  68.402973
# 66   20.0     0.0   120.0       0.0    1.0    1.00  0.67  72.801787
# 65   19.0     0.0   140.0       0.0    1.0    1.00  0.67  74.472949
# 4     8.0     0.0   330.0      25.0    3.0    1.00  0.50  93.704912
#
# [74 rows x 16 columns]

# %% [markdown]
# ## Pandas Basic Statistics

# %%
# Kalian bisa mengetahui secara cepat statistik sederhana dari data numerik, seperti mean, median, dll.
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   74.000000  74.000000  74.000000   74.000000  74.000000  74.000000
# mean   105.540541   2.500000   0.945946  160.675676   2.090541  14.594595
# std     18.442201   1.088546   0.963610   85.188447   2.404002   4.349205
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  131.250000   0.250000  12.000000
# 50%    110.000000   2.000000   1.000000  180.000000   1.500000  14.000000
# 75%    110.000000   3.000000   1.000000  217.500000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  74.000000   74.000000   74.000000  74.000000  74.000000  74.000000
# mean    6.770270   92.675676   28.378378   2.175676   1.027432   0.818243
# std     4.467684   70.578065   22.787104   0.833512   0.151260   0.234914
# min    -1.000000   -1.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000   40.000000   25.000000   1.000000   1.000000   0.670000
# 50%     6.000000   90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    10.750000  113.750000   25.000000   3.000000   1.000000   1.000000
# max    15.000000  330.000000  100.000000   3.000000   1.500000   1.500000
#
#           rating
# count  74.000000
# mean   42.879265
# std    14.280511
# min    18.042851
# 25%    32.449210
# 50%    40.424490
# 75%    51.401243
# max    93.704912

# %%
# Jika ingin satu-satu, kalian bisa gunakan command seperti berikut
df.fat.mean()
# Out:
# 0.9459459459459459

# %%
df.sodium.std()
# Out:
# 85.18844672264345

# %%
# Kalian juga bisa menemukan korelasi antara 2 variabel (seperti pada laporan praktikum)
df.calories.corr(df.rating)
# Out:
# -0.7120539091366642

# %%
# Urutan tidak berpengaruh
df.rating.corr(df.calories)
# Out:
# -0.7120539091366642

# %%
# Kalian juga dapat menemukan indeks baris yang bernilai maksimum dari sebuah kolom. Misalnya kita ambil contoh kolom fiber
idx = df.fiber.idxmax() # Untuk minimum, ganti idxmax() jadi idxmin()
df.iloc[idx]
# Out:
# name        Almond Delight
# mfr                      R
# type                     C
# calories               110
# protein                  2
# fat                      2
# sodium                 200
# fiber                  1.0
# carbo                 14.0
# sugars                 8.0
# potass                -1.0
# vitamins              25.0
# shelf                  3.0
# weight                 1.0
# cups                  0.75
# rating           34.384843
# Name: 5, dtype: object

# %% [markdown]
# Kenapa bentuknya vertikal? Karena dia berbentuk series, bukan dataframe. Jika penasaran perbedaan series dan dataframe, bisa kunjungi page [berikut](https://www.geeksforgeeks.org/creating-a-dataframe-from-pandas-series/#:~:text=Series%20can%20only%20contain%20single,used%20to%20analyse%20the%20data.&text=Explanation%3A&text=Metadata%20is%20the%20data%20of,define%20the%20series%20of%20values.)

# %% [markdown]
# ## Group By

# %%
# Kita bisa mengelompokkan kategori di dalam kolom. Apa maksudnya?
# Mari kita lihat ada nilai apa saja dalam kolom type
df.type.unique()
# Out:
# array(['C', 'H'], dtype=object)

# %%
# Dalam kolom tipe, ada C dan H. Ketika kita groupby, maka hanya akan ada dua kolom tersebut yang dikelompokkan. 
# Contohnya ketika kita ingin membandingkan rata-rata protein tipe C dan H

df.groupby("type").protein.mean()
# Out:
# type
# C    2.43662
# H    4.00000
# Name: protein, dtype: float64

# %%
# Kita juga bisa mengelompokkan mfr terlebih dahulu,
# kemudian mengelompokkan tipe
df.groupby(["mfr", "type"])['protein'].mean()
# Out:
# mfr  type
# A    H       4.000000
# G    C       2.318182
# K    C       2.652174
# N    C       2.800000
#      H       3.000000
# P    C       2.375000
# Q    C       2.285714
#      H       5.000000
# R    C       2.000000
# Name: protein, dtype: float64

# %%
# Perhatikan, ada perbedaan ketika dibalik (seperti sorting)
df.groupby(["type", "mfr"])['protein'].mean()
# Out:
# type  mfr
# C     G      2.318182
#       K      2.652174
#       N      2.800000
#       P      2.375000
#       Q      2.285714
#       R      2.000000
# H     A      4.000000
#       N      3.000000
#       Q      5.000000
# Name: protein, dtype: float64

# %% [markdown]
# # Selesai! :D

# %% [markdown]
# Okay! Sampai di sini dulu perjumpaan kita. Untuk tahap selanjutnya, kalian bisa belajar tentang visualisasi data. Sebenarnya, ada banyak resources di internet, beberapa di antaranya adalah Towards Data Science, Stack Overflow, dan Geeks for Geeks. Untuk mencoba hands-on lebih jauh, kalian bisa coba buat akun Kaggle. Mereka menyediakan course gratis dan komunitasnya bagus!
#
# Baiklah, saya pamit dulu, ya! Khelli mohon maaf apabila banyak yang kurang di artikel ini. Saya juga masih perlu banyak belajar tentang data. Jika ada saran mengenai artikel ini, disampaikan saja, ya! Semangat semuanya, khususnya adik-adik TPB ITB yang menempuh Mata Kuliah KU1102 Pengenalan Komputasi.
# <br> <br>
#
# Salam,
# <br> <br> <br>
# Maria Khelli
